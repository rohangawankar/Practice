# %%
import glob,os
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dirPath = 'C:/Users/Rohan/Downloads/trial-run-recruitment-task/trial-run-recruitment-task/data'
colNames = ['message','sentiment']
pattern = ".txt"

# %%
def findFilesInDir(dirPath, pattern):
    """Finds the list of filenames in `dirPath` that match `pattern`.
    
    dirPath : Path to the directory to find files in.
    pattern : A glob pattern to match filenames against.
    Returns : List of filenames in `dirPath` that match `pattern`.
    """
    os.chdir(dirPath)
    for file in glob.glob(pattern):
        print(file)

# %%
findFilesInDir("C:/Users/Rohan/Downloads/trial-run-recruitment-task/trial-run-recruitment-task/data","*.txt")
# Out:
# amazon_cells_labelled.txt
# imdb_labelled.txt
# readme.txt
# yelp_labelled.txt

# %%
 def readMessagesFromFile(fPath, colNames, **kwargs):
    """Reads a file with messages and corresponding sentiments and
    returns a pandas DataFrame.

    fPath    : Path to the file to read messages from.
    colNames : Column names for the returned DataFrame.
    Returns  : Pandas DataFrame containing messages and sentiments
               as columns.

    Sample Output:
                                                 message  sentiment
    0                           Wow... Loved this place.          1
    1  I learned that if an electric slicer is used t...        NaN
    2                   But they don't clean the chiles?        NaN
    3                                 Crust is not good.          0
    4          Not tasty and the texture was just nasty.          0

    """
    print pd.read_csv(fPath,names=colNames,sep="\t").head(5)

# %%
readMessagesFromFile("C:/Users/Rohan/Downloads/trial-run-recruitment-task/trial-run-recruitment-task/data/imdb_labelled.txt",colNames)
# Out:
#                                              message  sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
"""For files in directory that match a pattern, return a dictionary of
    pandas DataFrames labeled by the filepaths.

    dirPath         : Path to the directory to find files in.
    fileNamePattern : A glob pattern to match filenames against.
    dfColNames      : Column names for the returned DataFrame.
    Returns         : Dictionary of DataFrames labeled by the filepaths.

    """

def readMessagesFromDir(dirPath, fileNamePattern, dfColNames, **kwargs):
    
    filelist = os.listdir(dirPath)
    list = []
    for file in filelist:
        if file.endswith(fileNamePattern):
            df = pd.read_csv(dirPath+"/"+file,sep="\t",names=dfColNames)
            df['label'] = file #os.path.join(dirPath,file)
            list.append(df)
    frame = pd.concat(list).reset_index(drop=True)
   
    df_dict = frame.to_dict()
    #df_dict = {k: v[['message','sentiment']] for k,v in frame.groupby('filepath')}
    return df_dict

# %%
msgDFDict = readMessagesFromDir(dirPath,pattern,colNames)
msgDFDict
# Out:
# {'label': {0: 'amazon_cells_labelled.txt',
#   1: 'amazon_cells_labelled.txt',
#   2: 'amazon_cells_labelled.txt',
#   3: 'amazon_cells_labelled.txt',
#   4: 'amazon_cells_labelled.txt',
#   5: 'amazon_cells_labelled.txt',
#   6: 'amazon_cells_labelled.txt',
#   7: 'amazon_cells_labelled.txt',
#   8: 'amazon_cells_labelled.txt',
#   9: 'amazon_cells_labelled.txt',
#   10: 'amazon_cells_labelled.txt',
#   11: 'amazon_cells_labelled.txt',
#   12: 'amazon_cells_labelled.txt',
#   13: 'amazon_cells_labelled.txt',
#   14: 'amazon_cells_labelled.txt',
#   15: 'amazon_cells_labelled.txt',
#   16: 'amazon_cells_labelled.txt',
#   17: 'amazon_cells_labelled.txt',
#   18: 'amazon_cells_labelled.txt',
#   19: 'amazon_cells_labelled.txt',
#   20: 'amazon_cells_labelled.txt',
#   21: 'amazon_cells_labelled.txt',
#   22: 'amazon_cells_labelled.txt',
#   23: 'amazon_cells_labelled.txt',
#   24: 'amazon_cells_labelled.txt',
#   25: 'amazon_cells_labelled.txt',
#   26: 'amazon_cells_labelled.txt',
#   27: 'amazon_cells_labelled.txt',
#   28: 'amazon_cells_labelled.txt',
#   29: 'amazon_cells_labelled.txt',
#   30: 'amazon_cells_labelled.txt',
#   31: 'amazon_cells_labelled.txt',
#   32: 'amazon_cells_labelled.txt',
#   33: 'amazon_cells_labelled.txt',
#   34: 'amazon_cells_labelled.txt',
#   35: 'amazon_cells_labelled.txt',
#   36: 'amazon_cells_labelled.txt',
#   37: 'amazon_cells_labelled.txt',
#   38: 'amazon_cells_labelled.txt',
#   39: 'amazon_cells_labelled.txt',
#   40: 'amazon_cells_labelled.txt',
#   41: 'amazon_cells_labelled.txt',
#   42: 'amazon_cells_labelled.txt',
#   43: 'amazon_cells_labelled.txt',
#   44: 'amazon_cells_labelled.txt',
#   45: 'amazon_cells_labelled.txt',
#   46: 'amazon_cells_labelled.txt',
#   47: 'amazon_cells_labelled.txt',
#   48: 'amazon_cells_labelled.txt',
#   49: 'amazon_cells_labelled.txt',
#   50: 'amazon_cells_labelled.txt',
#   51: 'amazon_cells_labelled.txt',
#   52: 'amazon_cells_labelled.txt',
#   53: 'amazon_cells_labelled.txt',
#   54: 'amazon_cells_labelled.txt',
#   55: 'amazon_cells_labelled.txt',
#   56: 'amazon_cells_labelled.txt',
#   57: 'amazon_cells_labelled.txt',
#   58: 'amazon_cells_labelled.txt',
#   59: 'amazon_cells_labelled.txt',
#   60: 'amazon_cells_labelled.txt',
#   61: 'amazon_cells_labelled.txt',
#   62: 'amazon_cells_labelled.txt',
#   63: 'amazon_cells_labelled.txt',
#   64: 'amazon_cells_labelled.txt',
#   65: 'amazon_cells_labelled.txt',
#   66: 'amazon_cells_labelled.txt',
#   67: 'amazon_cells_labelled.txt',
#   68: 'amazon_cells_labelled.txt',
#   69: 'amazon_cells_labelled.txt',
#   70: 'amazon_cells_labelled.txt',
#   71: 'amazon_cells_labelled.txt',
#   72: 'amazon_cells_labelled.txt',
#   73: 'amazon_cells_labelled.txt',
#   74: 'amazon_cells_labelled.txt',
#   75: 'amazon_cells_labelled.txt',
#   76: 'amazon_cells_labelled.txt',
#   77: 'amazon_cells_labelled.txt',
#   78: 'amazon_cells_labelled.txt',
#   79: 'amazon_cells_labelled.txt',
#   80: 'amazon_cells_labelled.txt',
#   81: 'amazon_cells_labelled.txt',
#   82: 'amazon_cells_labelled.txt',
#   83: 'amazon_cells_labelled.txt',
#   84: 'amazon_cells_labelled.txt',
#   85: 'amazon_cells_labelled.txt',
#   86: 'amazon_cells_labelled.txt',
#   87: 'amazon_cells_labelled.txt',
#   88: 'amazon_cells_labelled.txt',
#   89: 'amazon_cells_labelled.txt',
#   90: 'amazon_cells_labelled.txt',
#   91: 'amazon_cells_labelled.txt',
#   92: 'amazon_cells_labelled.txt',
#   93: 'amazon_cells_labelled.txt',
#   94: 'amazon_cells_labelled.txt',
#   95: 'amazon_cells_labelled.txt',
#   96: 'amazon_cells_labelled.txt',
#   97: 'amazon_cells_labelled.txt',
#   98: 'amazon_cells_labelled.txt',
#   99: 'amazon_cells_labelled.txt',
#   100: 'amazon_cells_labelled.txt',
#   101: 'amazon_cells_labelled.txt',
#   102: 'amazon_cells_labelled.txt',
#   103: 'amazon_cells_labelled.txt',
#   104: 'amazon_cells_labelled.txt',
#   105: 'amazon_cells_labelled.txt',
#   106: 'amazon_cells_labelled.txt',
#   107: 'amazon_cells_labelled.txt',
#   108: 'amazon_cells_labelled.txt',
#   109: 'amazon_cells_labelled.txt',
#   110: 'amazon_cells_labelled.txt',
#   111: 'amazon_cells_labelled.txt',
#   112: 'amazon_cells_labelled.txt',
#   113: 'amazon_cells_labelled.txt',
#   114: 'amazon_cells_labelled.txt',
#   115: 'amazon_cells_labelled.txt',
#   116: 'amazon_cells_labelled.txt',
#   117: 'amazon_cells_labelled.txt',
#   118: 'amazon_cells_labelled.txt',
#   119: 'amazon_cells_labelled.txt',
#   120: 'amazon_cells_labelled.txt',
#   121: 'amazon_cells_labelled.txt',
#   122: 'amazon_cells_labelled.txt',
#   123: 'amazon_cells_labelled.txt',
#   124: 'amazon_cells_labelled.txt',
#   125: 'amazon_cells_labelled.txt',
#   126: 'amazon_cells_labelled.txt',
#   127: 'amazon_cells_labelled.txt',
#   128: 'amazon_cells_labelled.txt',
#   129: 'amazon_cells_labelled.txt',
#   130: 'amazon_cells_labelled.txt',
#   131: 'amazon_cells_labelled.txt',
#   132: 'amazon_cells_labelled.txt',
#   133: 'amazon_cells_labelled.txt',
#   134: 'amazon_cells_labelled.txt',
#   135: 'amazon_cells_labelled.txt',
#   136: 'amazon_cells_labelled.txt',
#   137: 'amazon_cells_labelled.txt',
#   138: 'amazon_cells_labelled.txt',
#   139: 'amazon_cells_labelled.txt',
#   140: 'amazon_cells_labelled.txt',
#   141: 'amazon_cells_labelled.txt',
#   142: 'amazon_cells_labelled.txt',
#   143: 'amazon_cells_labelled.txt',
#   144: 'amazon_cells_labelled.txt',
#   145: 'amazon_cells_labelled.txt',
#   146: 'amazon_cells_labelled.txt',
#   147: 'amazon_cells_labelled.txt',
#   148: 'amazon_cells_labelled.txt',
#   149: 'amazon_cells_labelled.txt',
#   150: 'amazon_cells_labelled.txt',
#   151: 'amazon_cells_labelled.txt',
#   152: 'amazon_cells_labelled.txt',
#   153: 'amazon_cells_labelled.txt',
#   154: 'amazon_cells_labelled.txt',
#   155: 'amazon_cells_labelled.txt',
#   156: 'amazon_cells_labelled.txt',
#   157: 'amazon_cells_labelled.txt',
#   158: 'amazon_cells_labelled.txt',
#   159: 'amazon_cells_labelled.txt',
#   160: 'amazon_cells_labelled.txt',
#   161: 'amazon_cells_labelled.txt',
#   162: 'amazon_cells_labelled.txt',
#   163: 'amazon_cells_labelled.txt',
#   164: 'amazon_cells_labelled.txt',
#   165: 'amazon_cells_labelled.txt',
#   166: 'amazon_cells_labelled.txt',
#   167: 'amazon_cells_labelled.txt',
#   168: 'amazon_cells_labelled.txt',
#   169: 'amazon_cells_labelled.txt',
#   170: 'amazon_cells_labelled.txt',
#   171: 'amazon_cells_labelled.txt',
#   172: 'amazon_cells_labelled.txt',
#   173: 'amazon_cells_labelled.txt',
#   174: 'amazon_cells_labelled.txt',
#   175: 'amazon_cells_labelled.txt',
#   176: 'amazon_cells_labelled.txt',
#   177: 'amazon_cells_labelled.txt',
#   178: 'amazon_cells_labelled.txt',
#   179: 'amazon_cells_labelled.txt',
#   180: 'amazon_cells_labelled.txt',
#   181: 'amazon_cells_labelled.txt',
#   182: 'amazon_cells_labelled.txt',
#   183: 'amazon_cells_labelled.txt',
#   184: 'amazon_cells_labelled.txt',
#   185: 'amazon_cells_labelled.txt',
#   186: 'amazon_cells_labelled.txt',
#   187: 'amazon_cells_labelled.txt',
#   188: 'amazon_cells_labelled.txt',
#   189: 'amazon_cells_labelled.txt',
#   190: 'amazon_cells_labelled.txt',
#   191: 'amazon_cells_labelled.txt',
#   192: 'amazon_cells_labelled.txt',
#   193: 'amazon_cells_labelled.txt',
#   194: 'amazon_cells_labelled.txt',
#   195: 'amazon_cells_labelled.txt',
#   196: 'amazon_cells_labelled.txt',
#   197: 'amazon_cells_labelled.txt',
#   198: 'amazon_cells_labelled.txt',
#   199: 'amazon_cells_labelled.txt',
#   200: 'amazon_cells_labelled.txt',
#   201: 'amazon_cells_labelled.txt',
#   202: 'amazon_cells_labelled.txt',
#   203: 'amazon_cells_labelled.txt',
#   204: 'amazon_cells_labelled.txt',
#   205: 'amazon_cells_labelled.txt',
#   206: 'amazon_cells_labelled.txt',
#   207: 'amazon_cells_labelled.txt',
#   208: 'amazon_cells_labelled.txt',
#   209: 'amazon_cells_labelled.txt',
#   210: 'amazon_cells_labelled.txt',
#   211: 'amazon_cells_labelled.txt',
#   212: 'amazon_cells_labelled.txt',
#   213: 'amazon_cells_labelled.txt',
#   214: 'amazon_cells_labelled.txt',
#   215: 'amazon_cells_labelled.txt',
#   216: 'amazon_cells_labelled.txt',
#   217: 'amazon_cells_labelled.txt',
#   218: 'amazon_cells_labelled.txt',
#   219: 'amazon_cells_labelled.txt',
#   220: 'amazon_cells_labelled.txt',
#   221: 'amazon_cells_labelled.txt',
#   222: 'amazon_cells_labelled.txt',
#   223: 'amazon_cells_labelled.txt',
#   224: 'amazon_cells_labelled.txt',
#   225: 'amazon_cells_labelled.txt',
#   226: 'amazon_cells_labelled.txt',
#   227: 'amazon_cells_labelled.txt',
#   228: 'amazon_cells_labelled.txt',
#   229: 'amazon_cells_labelled.txt',
#   230: 'amazon_cells_labelled.txt',
#   231: 'amazon_cells_labelled.txt',
#   232: 'amazon_cells_labelled.txt',
#   233: 'amazon_cells_labelled.txt',
#   234: 'amazon_cells_labelled.txt',
#   235: 'amazon_cells_labelled.txt',
#   236: 'amazon_cells_labelled.txt',
#   237: 'amazon_cells_labelled.txt',
#   238: 'amazon_cells_labelled.txt',
#   239: 'amazon_cells_labelled.txt',
#   240: 'amazon_cells_labelled.txt',
#   241: 'amazon_cells_labelled.txt',
#   242: 'amazon_cells_labelled.txt',
#   243: 'amazon_cells_labelled.txt',
#   244: 'amazon_cells_labelled.txt',
#   245: 'amazon_cells_labelled.txt',
#   246: 'amazon_cells_labelled.txt',
#   247: 'amazon_cells_labelled.txt',
#   248: 'amazon_cells_labelled.txt',
#   249: 'amazon_cells_labelled.txt',
#   250: 'amazon_cells_labelled.txt',
#   251: 'amazon_cells_labelled.txt',
#   252: 'amazon_cells_labelled.txt',
#   253: 'amazon_cells_labelled.txt',
#   254: 'amazon_cells_labelled.txt',
#   255: 'amazon_cells_labelled.txt',
#   256: 'amazon_cells_labelled.txt',
#   257: 'amazon_cells_labelled.txt',
#   258: 'amazon_cells_labelled.txt',
#   259: 'amazon_cells_labelled.txt',
#   260: 'amazon_cells_labelled.txt',
#   261: 'amazon_cells_labelled.txt',
#   262: 'amazon_cells_labelled.txt',
#   263: 'amazon_cells_labelled.txt',
#   264: 'amazon_cells_labelled.txt',
#   265: 'amazon_cells_labelled.txt',
#   266: 'amazon_cells_labelled.txt',
#   267: 'amazon_cells_labelled.txt',
#   268: 'amazon_cells_labelled.txt',
#   269: 'amazon_cells_labelled.txt',
#   270: 'amazon_cells_labelled.txt',
#   271: 'amazon_cells_labelled.txt',
#   272: 'amazon_cells_labelled.txt',
#   273: 'amazon_cells_labelled.txt',
#   274: 'amazon_cells_labelled.txt',
#   275: 'amazon_cells_labelled.txt',
#   276: 'amazon_cells_labelled.txt',
#   277: 'amazon_cells_labelled.txt',
#   278: 'amazon_cells_labelled.txt',
#   279: 'amazon_cells_labelled.txt',
#   280: 'amazon_cells_labelled.txt',
#   281: 'amazon_cells_labelled.txt',
#   282: 'amazon_cells_labelled.txt',
#   283: 'amazon_cells_labelled.txt',
#   284: 'amazon_cells_labelled.txt',
#   285: 'amazon_cells_labelled.txt',
#   286: 'amazon_cells_labelled.txt',
#   287: 'amazon_cells_labelled.txt',
#   288: 'amazon_cells_labelled.txt',
#   289: 'amazon_cells_labelled.txt',
#   290: 'amazon_cells_labelled.txt',
#   291: 'amazon_cells_labelled.txt',
#   292: 'amazon_cells_labelled.txt',
#   293: 'amazon_cells_labelled.txt',
#   294: 'amazon_cells_labelled.txt',
#   295: 'amazon_cells_labelled.txt',
#   296: 'amazon_cells_labelled.txt',
#   297: 'amazon_cells_labelled.txt',
#   298: 'amazon_cells_labelled.txt',
#   299: 'amazon_cells_labelled.txt',
#   300: 'amazon_cells_labelled.txt',
#   301: 'amazon_cells_labelled.txt',
#   302: 'amazon_cells_labelled.txt',
#   303: 'amazon_cells_labelled.txt',
#   304: 'amazon_cells_labelled.txt',
#   305: 'amazon_cells_labelled.txt',
#   306: 'amazon_cells_labelled.txt',
#   307: 'amazon_cells_labelled.txt',
#   308: 'amazon_cells_labelled.txt',
#   309: 'amazon_cells_labelled.txt',
#   310: 'amazon_cells_labelled.txt',
#   311: 'amazon_cells_labelled.txt',
#   312: 'amazon_cells_labelled.txt',
#   313: 'amazon_cells_labelled.txt',
#   314: 'amazon_cells_labelled.txt',
#   315: 'amazon_cells_labelled.txt',
#   316: 'amazon_cells_labelled.txt',
#   317: 'amazon_cells_labelled.txt',
#   318: 'amazon_cells_labelled.txt',
#   319: 'amazon_cells_labelled.txt',
#   320: 'amazon_cells_labelled.txt',
#   321: 'amazon_cells_labelled.txt',
#   322: 'amazon_cells_labelled.txt',
#   323: 'amazon_cells_labelled.txt',
#   324: 'amazon_cells_labelled.txt',
#   325: 'amazon_cells_labelled.txt',
#   326: 'amazon_cells_labelled.txt',
#   327: 'amazon_cells_labelled.txt',
#   328: 'amazon_cells_labelled.txt',
#   329: 'amazon_cells_labelled.txt',
#   330: 'amazon_cells_labelled.txt',
#   331: 'amazon_cells_labelled.txt',
#   332: 'amazon_cells_labelled.txt',
#   333: 'amazon_cells_labelled.txt',
#   334: 'amazon_cells_labelled.txt',
#   335: 'amazon_cells_labelled.txt',
#   336: 'amazon_cells_labelled.txt',
#   337: 'amazon_cells_labelled.txt',
#   338: 'amazon_cells_labelled.txt',
#   339: 'amazon_cells_labelled.txt',
#   340: 'amazon_cells_labelled.txt',
#   341: 'amazon_cells_labelled.txt',
#   342: 'amazon_cells_labelled.txt',
#   343: 'amazon_cells_labelled.txt',
#   344: 'amazon_cells_labelled.txt',
#   345: 'amazon_cells_labelled.txt',
#   346: 'amazon_cells_labelled.txt',
#   347: 'amazon_cells_labelled.txt',
#   348: 'amazon_cells_labelled.txt',
#   349: 'amazon_cells_labelled.txt',
#   350: 'amazon_cells_labelled.txt',
#   351: 'amazon_cells_labelled.txt',
#   352: 'amazon_cells_labelled.txt',
#   353: 'amazon_cells_labelled.txt',
#   354: 'amazon_cells_labelled.txt',
#   355: 'amazon_cells_labelled.txt',
#   356: 'amazon_cells_labelled.txt',
#   357: 'amazon_cells_labelled.txt',
#   358: 'amazon_cells_labelled.txt',
#   359: 'amazon_cells_labelled.txt',
#   360: 'amazon_cells_labelled.txt',
#   361: 'amazon_cells_labelled.txt',
#   362: 'amazon_cells_labelled.txt',
#   363: 'amazon_cells_labelled.txt',
#   364: 'amazon_cells_labelled.txt',
#   365: 'amazon_cells_labelled.txt',
#   366: 'amazon_cells_labelled.txt',
#   367: 'amazon_cells_labelled.txt',
#   368: 'amazon_cells_labelled.txt',
#   369: 'amazon_cells_labelled.txt',
#   370: 'amazon_cells_labelled.txt',
#   371: 'amazon_cells_labelled.txt',
#   372: 'amazon_cells_labelled.txt',
#   373: 'amazon_cells_labelled.txt',
#   374: 'amazon_cells_labelled.txt',
#   375: 'amazon_cells_labelled.txt',
#   376: 'amazon_cells_labelled.txt',
#   377: 'amazon_cells_labelled.txt',
#   378: 'amazon_cells_labelled.txt',
#   379: 'amazon_cells_labelled.txt',
#   380: 'amazon_cells_labelled.txt',
#   381: 'amazon_cells_labelled.txt',
#   382: 'amazon_cells_labelled.txt',
#   383: 'amazon_cells_labelled.txt',
#   384: 'amazon_cells_labelled.txt',
#   385: 'amazon_cells_labelled.txt',
#   386: 'amazon_cells_labelled.txt',
#   387: 'amazon_cells_labelled.txt',
#   388: 'amazon_cells_labelled.txt',
#   389: 'amazon_cells_labelled.txt',
#   390: 'amazon_cells_labelled.txt',
#   391: 'amazon_cells_labelled.txt',
#   392: 'amazon_cells_labelled.txt',
#   393: 'amazon_cells_labelled.txt',
#   394: 'amazon_cells_labelled.txt',
#   395: 'amazon_cells_labelled.txt',
#   396: 'amazon_cells_labelled.txt',
#   397: 'amazon_cells_labelled.txt',
#   398: 'amazon_cells_labelled.txt',
#   399: 'amazon_cells_labelled.txt',
#   400: 'amazon_cells_labelled.txt',
#   401: 'amazon_cells_labelled.txt',
#   402: 'amazon_cells_labelled.txt',
#   403: 'amazon_cells_labelled.txt',
#   404: 'amazon_cells_labelled.txt',
#   405: 'amazon_cells_labelled.txt',
#   406: 'amazon_cells_labelled.txt',
#   407: 'amazon_cells_labelled.txt',
#   408: 'amazon_cells_labelled.txt',
#   409: 'amazon_cells_labelled.txt',
#   410: 'amazon_cells_labelled.txt',
#   411: 'amazon_cells_labelled.txt',
#   412: 'amazon_cells_labelled.txt',
#   413: 'amazon_cells_labelled.txt',
#   414: 'amazon_cells_labelled.txt',
#   415: 'amazon_cells_labelled.txt',
#   416: 'amazon_cells_labelled.txt',
#   417: 'amazon_cells_labelled.txt',
#   418: 'amazon_cells_labelled.txt',
#   419: 'amazon_cells_labelled.txt',
#   420: 'amazon_cells_labelled.txt',
#   421: 'amazon_cells_labelled.txt',
#   422: 'amazon_cells_labelled.txt',
#   423: 'amazon_cells_labelled.txt',
#   424: 'amazon_cells_labelled.txt',
#   425: 'amazon_cells_labelled.txt',
#   426: 'amazon_cells_labelled.txt',
#   427: 'amazon_cells_labelled.txt',
#   428: 'amazon_cells_labelled.txt',
#   429: 'amazon_cells_labelled.txt',
#   430: 'amazon_cells_labelled.txt',
#   431: 'amazon_cells_labelled.txt',
#   432: 'amazon_cells_labelled.txt',
#   433: 'amazon_cells_labelled.txt',
#   434: 'amazon_cells_labelled.txt',
#   435: 'amazon_cells_labelled.txt',
#   436: 'amazon_cells_labelled.txt',
#   437: 'amazon_cells_labelled.txt',
#   438: 'amazon_cells_labelled.txt',
#   439: 'amazon_cells_labelled.txt',
#   440: 'amazon_cells_labelled.txt',
#   441: 'amazon_cells_labelled.txt',
#   442: 'amazon_cells_labelled.txt',
#   443: 'amazon_cells_labelled.txt',
#   444: 'amazon_cells_labelled.txt',
#   445: 'amazon_cells_labelled.txt',
#   446: 'amazon_cells_labelled.txt',
#   447: 'amazon_cells_labelled.txt',
#   448: 'amazon_cells_labelled.txt',
#   449: 'amazon_cells_labelled.txt',
#   450: 'amazon_cells_labelled.txt',
#   451: 'amazon_cells_labelled.txt',
#   452: 'amazon_cells_labelled.txt',
#   453: 'amazon_cells_labelled.txt',
#   454: 'amazon_cells_labelled.txt',
#   455: 'amazon_cells_labelled.txt',
#   456: 'amazon_cells_labelled.txt',
#   457: 'amazon_cells_labelled.txt',
#   458: 'amazon_cells_labelled.txt',
#   459: 'amazon_cells_labelled.txt',
#   460: 'amazon_cells_labelled.txt',
#   461: 'amazon_cells_labelled.txt',
#   462: 'amazon_cells_labelled.txt',
#   463: 'amazon_cells_labelled.txt',
#   464: 'amazon_cells_labelled.txt',
#   465: 'amazon_cells_labelled.txt',
#   466: 'amazon_cells_labelled.txt',
#   467: 'amazon_cells_labelled.txt',
#   468: 'amazon_cells_labelled.txt',
#   469: 'amazon_cells_labelled.txt',
#   470: 'amazon_cells_labelled.txt',
#   471: 'amazon_cells_labelled.txt',
#   472: 'amazon_cells_labelled.txt',
#   473: 'amazon_cells_labelled.txt',
#   474: 'amazon_cells_labelled.txt',
#   475: 'amazon_cells_labelled.txt',
#   476: 'amazon_cells_labelled.txt',
#   477: 'amazon_cells_labelled.txt',
#   478: 'amazon_cells_labelled.txt',
#   479: 'amazon_cells_labelled.txt',
#   480: 'amazon_cells_labelled.txt',
#   481: 'amazon_cells_labelled.txt',
#   482: 'amazon_cells_labelled.txt',
#   483: 'amazon_cells_labelled.txt',
#   484: 'amazon_cells_labelled.txt',
#   485: 'amazon_cells_labelled.txt',
#   486: 'amazon_cells_labelled.txt',
#   487: 'amazon_cells_labelled.txt',
#   488: 'amazon_cells_labelled.txt',
#   489: 'amazon_cells_labelled.txt',
#   490: 'amazon_cells_labelled.txt',
#   491: 'amazon_cells_labelled.txt',
#   492: 'amazon_cells_labelled.txt',
#   493: 'amazon_cells_labelled.txt',
#   494: 'amazon_cells_labelled.txt',
#   495: 'amazon_cells_labelled.txt',
#   496: 'amazon_cells_labelled.txt',
#   497: 'amazon_cells_labelled.txt',
#   498: 'amazon_cells_labelled.txt',
#   499: 'amazon_cells_labelled.txt',
#   500: 'amazon_cells_labelled.txt',
#   501: 'amazon_cells_labelled.txt',
#   502: 'amazon_cells_labelled.txt',
#   503: 'amazon_cells_labelled.txt',
#   504: 'amazon_cells_labelled.txt',
#   505: 'amazon_cells_labelled.txt',
#   506: 'amazon_cells_labelled.txt',
#   507: 'amazon_cells_labelled.txt',
#   508: 'amazon_cells_labelled.txt',
#   509: 'amazon_cells_labelled.txt',
#   510: 'amazon_cells_labelled.txt',
#   511: 'amazon_cells_labelled.txt',
#   512: 'amazon_cells_labelled.txt',
#   513: 'amazon_cells_labelled.txt',
#   514: 'amazon_cells_labelled.txt',
#   515: 'amazon_cells_labelled.txt',
#   516: 'amazon_cells_labelled.txt',
#   517: 'amazon_cells_labelled.txt',
#   518: 'amazon_cells_labelled.txt',
#   519: 'amazon_cells_labelled.txt',
#   520: 'amazon_cells_labelled.txt',
#   521: 'amazon_cells_labelled.txt',
#   522: 'amazon_cells_labelled.txt',
#   523: 'amazon_cells_labelled.txt',
#   524: 'amazon_cells_labelled.txt',
#   525: 'amazon_cells_labelled.txt',
#   526: 'amazon_cells_labelled.txt',
#   527: 'amazon_cells_labelled.txt',
#   528: 'amazon_cells_labelled.txt',
#   529: 'amazon_cells_labelled.txt',
#   530: 'amazon_cells_labelled.txt',
#   531: 'amazon_cells_labelled.txt',
#   532: 'amazon_cells_labelled.txt',
#   533: 'amazon_cells_labelled.txt',
#   534: 'amazon_cells_labelled.txt',
#   535: 'amazon_cells_labelled.txt',
#   536: 'amazon_cells_labelled.txt',
#   537: 'amazon_cells_labelled.txt',
#   538: 'amazon_cells_labelled.txt',
#   539: 'amazon_cells_labelled.txt',
#   540: 'amazon_cells_labelled.txt',
#   541: 'amazon_cells_labelled.txt',
#   542: 'amazon_cells_labelled.txt',
#   543: 'amazon_cells_labelled.txt',
#   544: 'amazon_cells_labelled.txt',
#   545: 'amazon_cells_labelled.txt',
#   546: 'amazon_cells_labelled.txt',
#   547: 'amazon_cells_labelled.txt',
#   548: 'amazon_cells_labelled.txt',
#   549: 'amazon_cells_labelled.txt',
#   550: 'amazon_cells_labelled.txt',
#   551: 'amazon_cells_labelled.txt',
#   552: 'amazon_cells_labelled.txt',
#   553: 'amazon_cells_labelled.txt',
#   554: 'amazon_cells_labelled.txt',
#   555: 'amazon_cells_labelled.txt',
#   556: 'amazon_cells_labelled.txt',
#   557: 'amazon_cells_labelled.txt',
#   558: 'amazon_cells_labelled.txt',
#   559: 'amazon_cells_labelled.txt',
#   560: 'amazon_cells_labelled.txt',
#   561: 'amazon_cells_labelled.txt',
#   562: 'amazon_cells_labelled.txt',
#   563: 'amazon_cells_labelled.txt',
#   564: 'amazon_cells_labelled.txt',
#   565: 'amazon_cells_labelled.txt',
#   566: 'amazon_cells_labelled.txt',
#   567: 'amazon_cells_labelled.txt',
#   568: 'amazon_cells_labelled.txt',
#   569: 'amazon_cells_labelled.txt',
#   570: 'amazon_cells_labelled.txt',
#   571: 'amazon_cells_labelled.txt',
#   572: 'amazon_cells_labelled.txt',
#   573: 'amazon_cells_labelled.txt',
#   574: 'amazon_cells_labelled.txt',
#   575: 'amazon_cells_labelled.txt',
#   576: 'amazon_cells_labelled.txt',
#   577: 'amazon_cells_labelled.txt',
#   578: 'amazon_cells_labelled.txt',
#   579: 'amazon_cells_labelled.txt',
#   580: 'amazon_cells_labelled.txt',
#   581: 'amazon_cells_labelled.txt',
#   582: 'amazon_cells_labelled.txt',
#   583: 'amazon_cells_labelled.txt',
#   584: 'amazon_cells_labelled.txt',
#   585: 'amazon_cells_labelled.txt',
#   586: 'amazon_cells_labelled.txt',
#   587: 'amazon_cells_labelled.txt',
#   588: 'amazon_cells_labelled.txt',
#   589: 'amazon_cells_labelled.txt',
#   590: 'amazon_cells_labelled.txt',
#   591: 'amazon_cells_labelled.txt',
#   592: 'amazon_cells_labelled.txt',
#   593: 'amazon_cells_labelled.txt',
#   594: 'amazon_cells_labelled.txt',
#   595: 'amazon_cells_labelled.txt',
#   596: 'amazon_cells_labelled.txt',
#   597: 'amazon_cells_labelled.txt',
#   598: 'amazon_cells_labelled.txt',
#   599: 'amazon_cells_labelled.txt',
#   600: 'amazon_cells_labelled.txt',
#   601: 'amazon_cells_labelled.txt',
#   602: 'amazon_cells_labelled.txt',
#   603: 'amazon_cells_labelled.txt',
#   604: 'amazon_cells_labelled.txt',
#   605: 'amazon_cells_labelled.txt',
#   606: 'amazon_cells_labelled.txt',
#   607: 'amazon_cells_labelled.txt',
#   608: 'amazon_cells_labelled.txt',
#   609: 'amazon_cells_labelled.txt',
#   610: 'amazon_cells_labelled.txt',
#   611: 'amazon_cells_labelled.txt',
#   612: 'amazon_cells_labelled.txt',
#   613: 'amazon_cells_labelled.txt',
#   614: 'amazon_cells_labelled.txt',
#   615: 'amazon_cells_labelled.txt',
#   616: 'amazon_cells_labelled.txt',
#   617: 'amazon_cells_labelled.txt',
#   618: 'amazon_cells_labelled.txt',
#   619: 'amazon_cells_labelled.txt',
#   620: 'amazon_cells_labelled.txt',
#   621: 'amazon_cells_labelled.txt',
#   622: 'amazon_cells_labelled.txt',
#   623: 'amazon_cells_labelled.txt',
#   624: 'amazon_cells_labelled.txt',
#   625: 'amazon_cells_labelled.txt',
#   626: 'amazon_cells_labelled.txt',
#   627: 'amazon_cells_labelled.txt',
#   628: 'amazon_cells_labelled.txt',
#   629: 'amazon_cells_labelled.txt',
#   630: 'amazon_cells_labelled.txt',
#   631: 'amazon_cells_labelled.txt',
#   632: 'amazon_cells_labelled.txt',
#   633: 'amazon_cells_labelled.txt',
#   634: 'amazon_cells_labelled.txt',
#   635: 'amazon_cells_labelled.txt',
#   636: 'amazon_cells_labelled.txt',
#   637: 'amazon_cells_labelled.txt',
#   638: 'amazon_cells_labelled.txt',
#   639: 'amazon_cells_labelled.txt',
#   640: 'amazon_cells_labelled.txt',
#   641: 'amazon_cells_labelled.txt',
#   642: 'amazon_cells_labelled.txt',
#   643: 'amazon_cells_labelled.txt',
#   644: 'amazon_cells_labelled.txt',
#   645: 'amazon_cells_labelled.txt',
#   646: 'amazon_cells_labelled.txt',
#   647: 'amazon_cells_labelled.txt',
#   648: 'amazon_cells_labelled.txt',
#   649: 'amazon_cells_labelled.txt',
#   650: 'amazon_cells_labelled.txt',
#   651: 'amazon_cells_labelled.txt',
#   652: 'amazon_cells_labelled.txt',
#   653: 'amazon_cells_labelled.txt',
#   654: 'amazon_cells_labelled.txt',
#   655: 'amazon_cells_labelled.txt',
#   656: 'amazon_cells_labelled.txt',
#   657: 'amazon_cells_labelled.txt',
#   658: 'amazon_cells_labelled.txt',
#   659: 'amazon_cells_labelled.txt',
#   660: 'amazon_cells_labelled.txt',
#   661: 'amazon_cells_labelled.txt',
#   662: 'amazon_cells_labelled.txt',
#   663: 'amazon_cells_labelled.txt',
#   664: 'amazon_cells_labelled.txt',
#   665: 'amazon_cells_labelled.txt',
#   666: 'amazon_cells_labelled.txt',
#   667: 'amazon_cells_labelled.txt',
#   668: 'amazon_cells_labelled.txt',
#   669: 'amazon_cells_labelled.txt',
#   670: 'amazon_cells_labelled.txt',
#   671: 'amazon_cells_labelled.txt',
#   672: 'amazon_cells_labelled.txt',
#   673: 'amazon_cells_labelled.txt',
#   674: 'amazon_cells_labelled.txt',
#   675: 'amazon_cells_labelled.txt',
#   676: 'amazon_cells_labelled.txt',
#   677: 'amazon_cells_labelled.txt',
#   678: 'amazon_cells_labelled.txt',
#   679: 'amazon_cells_labelled.txt',
#   680: 'amazon_cells_labelled.txt',
#   681: 'amazon_cells_labelled.txt',
#   682: 'amazon_cells_labelled.txt',
#   683: 'amazon_cells_labelled.txt',
#   684: 'amazon_cells_labelled.txt',
#   685: 'amazon_cells_labelled.txt',
#   686: 'amazon_cells_labelled.txt',
#   687: 'amazon_cells_labelled.txt',
#   688: 'amazon_cells_labelled.txt',
#   689: 'amazon_cells_labelled.txt',
#   690: 'amazon_cells_labelled.txt',
#   691: 'amazon_cells_labelled.txt',
#   692: 'amazon_cells_labelled.txt',
#   693: 'amazon_cells_labelled.txt',
#   694: 'amazon_cells_labelled.txt',
#   695: 'amazon_cells_labelled.txt',
#   696: 'amazon_cells_labelled.txt',
#   697: 'amazon_cells_labelled.txt',
#   698: 'amazon_cells_labelled.txt',
#   699: 'amazon_cells_labelled.txt',
#   700: 'amazon_cells_labelled.txt',
#   701: 'amazon_cells_labelled.txt',
#   702: 'amazon_cells_labelled.txt',
#   703: 'amazon_cells_labelled.txt',
#   704: 'amazon_cells_labelled.txt',
#   705: 'amazon_cells_labelled.txt',
#   706: 'amazon_cells_labelled.txt',
#   707: 'amazon_cells_labelled.txt',
#   708: 'amazon_cells_labelled.txt',
#   709: 'amazon_cells_labelled.txt',
#   710: 'amazon_cells_labelled.txt',
#   711: 'amazon_cells_labelled.txt',
#   712: 'amazon_cells_labelled.txt',
#   713: 'amazon_cells_labelled.txt',
#   714: 'amazon_cells_labelled.txt',
#   715: 'amazon_cells_labelled.txt',
#   716: 'amazon_cells_labelled.txt',
#   717: 'amazon_cells_labelled.txt',
#   718: 'amazon_cells_labelled.txt',
#   719: 'amazon_cells_labelled.txt',
#   720: 'amazon_cells_labelled.txt',
#   721: 'amazon_cells_labelled.txt',
#   722: 'amazon_cells_labelled.txt',
#   723: 'amazon_cells_labelled.txt',
#   724: 'amazon_cells_labelled.txt',
#   725: 'amazon_cells_labelled.txt',
#   726: 'amazon_cells_labelled.txt',
#   727: 'amazon_cells_labelled.txt',
#   728: 'amazon_cells_labelled.txt',
#   729: 'amazon_cells_labelled.txt',
#   730: 'amazon_cells_labelled.txt',
#   731: 'amazon_cells_labelled.txt',
#   732: 'amazon_cells_labelled.txt',
#   733: 'amazon_cells_labelled.txt',
#   734: 'amazon_cells_labelled.txt',
#   735: 'amazon_cells_labelled.txt',
#   736: 'amazon_cells_labelled.txt',
#   737: 'amazon_cells_labelled.txt',
#   738: 'amazon_cells_labelled.txt',
#   739: 'amazon_cells_labelled.txt',
#   740: 'amazon_cells_labelled.txt',
#   741: 'amazon_cells_labelled.txt',
#   742: 'amazon_cells_labelled.txt',
#   743: 'amazon_cells_labelled.txt',
#   744: 'amazon_cells_labelled.txt',
#   745: 'amazon_cells_labelled.txt',
#   746: 'amazon_cells_labelled.txt',
#   747: 'amazon_cells_labelled.txt',
#   748: 'amazon_cells_labelled.txt',
#   749: 'amazon_cells_labelled.txt',
#   750: 'amazon_cells_labelled.txt',
#   751: 'amazon_cells_labelled.txt',
#   752: 'amazon_cells_labelled.txt',
#   753: 'amazon_cells_labelled.txt',
#   754: 'amazon_cells_labelled.txt',
#   755: 'amazon_cells_labelled.txt',
#   756: 'amazon_cells_labelled.txt',
#   757: 'amazon_cells_labelled.txt',
#   758: 'amazon_cells_labelled.txt',
#   759: 'amazon_cells_labelled.txt',
#   760: 'amazon_cells_labelled.txt',
#   761: 'amazon_cells_labelled.txt',
#   762: 'amazon_cells_labelled.txt',
#   763: 'amazon_cells_labelled.txt',
#   764: 'amazon_cells_labelled.txt',
#   765: 'amazon_cells_labelled.txt',
#   766: 'amazon_cells_labelled.txt',
#   767: 'amazon_cells_labelled.txt',
#   768: 'amazon_cells_labelled.txt',
#   769: 'amazon_cells_labelled.txt',
#   770: 'amazon_cells_labelled.txt',
#   771: 'amazon_cells_labelled.txt',
#   772: 'amazon_cells_labelled.txt',
#   773: 'amazon_cells_labelled.txt',
#   774: 'amazon_cells_labelled.txt',
#   775: 'amazon_cells_labelled.txt',
#   776: 'amazon_cells_labelled.txt',
#   777: 'amazon_cells_labelled.txt',
#   778: 'amazon_cells_labelled.txt',
#   779: 'amazon_cells_labelled.txt',
#   780: 'amazon_cells_labelled.txt',
#   781: 'amazon_cells_labelled.txt',
#   782: 'amazon_cells_labelled.txt',
#   783: 'amazon_cells_labelled.txt',
#   784: 'amazon_cells_labelled.txt',
#   785: 'amazon_cells_labelled.txt',
#   786: 'amazon_cells_labelled.txt',
#   787: 'amazon_cells_labelled.txt',
#   788: 'amazon_cells_labelled.txt',
#   789: 'amazon_cells_labelled.txt',
#   790: 'amazon_cells_labelled.txt',
#   791: 'amazon_cells_labelled.txt',
#   792: 'amazon_cells_labelled.txt',
#   793: 'amazon_cells_labelled.txt',
#   794: 'amazon_cells_labelled.txt',
#   795: 'amazon_cells_labelled.txt',
#   796: 'amazon_cells_labelled.txt',
#   797: 'amazon_cells_labelled.txt',
#   798: 'amazon_cells_labelled.txt',
#   799: 'amazon_cells_labelled.txt',
#   800: 'amazon_cells_labelled.txt',
#   801: 'amazon_cells_labelled.txt',
#   802: 'amazon_cells_labelled.txt',
#   803: 'amazon_cells_labelled.txt',
#   804: 'amazon_cells_labelled.txt',
#   805: 'amazon_cells_labelled.txt',
#   806: 'amazon_cells_labelled.txt',
#   807: 'amazon_cells_labelled.txt',
#   808: 'amazon_cells_labelled.txt',
#   809: 'amazon_cells_labelled.txt',
#   810: 'amazon_cells_labelled.txt',
#   811: 'amazon_cells_labelled.txt',
#   812: 'amazon_cells_labelled.txt',
#   813: 'amazon_cells_labelled.txt',
#   814: 'amazon_cells_labelled.txt',
#   815: 'amazon_cells_labelled.txt',
#   816: 'amazon_cells_labelled.txt',
#   817: 'amazon_cells_labelled.txt',
#   818: 'amazon_cells_labelled.txt',
#   819: 'amazon_cells_labelled.txt',
#   820: 'amazon_cells_labelled.txt',
#   821: 'amazon_cells_labelled.txt',
#   822: 'amazon_cells_labelled.txt',
#   823: 'amazon_cells_labelled.txt',
#   824: 'amazon_cells_labelled.txt',
#   825: 'amazon_cells_labelled.txt',
#   826: 'amazon_cells_labelled.txt',
#   827: 'amazon_cells_labelled.txt',
#   828: 'amazon_cells_labelled.txt',
#   829: 'amazon_cells_labelled.txt',
#   830: 'amazon_cells_labelled.txt',
#   831: 'amazon_cells_labelled.txt',
#   832: 'amazon_cells_labelled.txt',
#   833: 'amazon_cells_labelled.txt',
#   834: 'amazon_cells_labelled.txt',
#   835: 'amazon_cells_labelled.txt',
#   836: 'amazon_cells_labelled.txt',
#   837: 'amazon_cells_labelled.txt',
#   838: 'amazon_cells_labelled.txt',
#   839: 'amazon_cells_labelled.txt',
#   840: 'amazon_cells_labelled.txt',
#   841: 'amazon_cells_labelled.txt',
#   842: 'amazon_cells_labelled.txt',
#   843: 'amazon_cells_labelled.txt',
#   844: 'amazon_cells_labelled.txt',
#   845: 'amazon_cells_labelled.txt',
#   846: 'amazon_cells_labelled.txt',
#   847: 'amazon_cells_labelled.txt',
#   848: 'amazon_cells_labelled.txt',
#   849: 'amazon_cells_labelled.txt',
#   850: 'amazon_cells_labelled.txt',
#   851: 'amazon_cells_labelled.txt',
#   852: 'amazon_cells_labelled.txt',
#   853: 'amazon_cells_labelled.txt',
#   854: 'amazon_cells_labelled.txt',
#   855: 'amazon_cells_labelled.txt',
#   856: 'amazon_cells_labelled.txt',
#   857: 'amazon_cells_labelled.txt',
#   858: 'amazon_cells_labelled.txt',
#   859: 'amazon_cells_labelled.txt',
#   860: 'amazon_cells_labelled.txt',
#   861: 'amazon_cells_labelled.txt',
#   862: 'amazon_cells_labelled.txt',
#   863: 'amazon_cells_labelled.txt',
#   864: 'amazon_cells_labelled.txt',
#   865: 'amazon_cells_labelled.txt',
#   866: 'amazon_cells_labelled.txt',
#   867: 'amazon_cells_labelled.txt',
#   868: 'amazon_cells_labelled.txt',
#   869: 'amazon_cells_labelled.txt',
#   870: 'amazon_cells_labelled.txt',
#   871: 'amazon_cells_labelled.txt',
#   872: 'amazon_cells_labelled.txt',
#   873: 'amazon_cells_labelled.txt',
#   874: 'amazon_cells_labelled.txt',
#   875: 'amazon_cells_labelled.txt',
#   876: 'amazon_cells_labelled.txt',
#   877: 'amazon_cells_labelled.txt',
#   878: 'amazon_cells_labelled.txt',
#   879: 'amazon_cells_labelled.txt',
#   880: 'amazon_cells_labelled.txt',
#   881: 'amazon_cells_labelled.txt',
#   882: 'amazon_cells_labelled.txt',
#   883: 'amazon_cells_labelled.txt',
#   884: 'amazon_cells_labelled.txt',
#   885: 'amazon_cells_labelled.txt',
#   886: 'amazon_cells_labelled.txt',
#   887: 'amazon_cells_labelled.txt',
#   888: 'amazon_cells_labelled.txt',
#   889: 'amazon_cells_labelled.txt',
#   890: 'amazon_cells_labelled.txt',
#   891: 'amazon_cells_labelled.txt',
#   892: 'amazon_cells_labelled.txt',
#   893: 'amazon_cells_labelled.txt',
#   894: 'amazon_cells_labelled.txt',
#   895: 'amazon_cells_labelled.txt',
#   896: 'amazon_cells_labelled.txt',
#   897: 'amazon_cells_labelled.txt',
#   898: 'amazon_cells_labelled.txt',
#   899: 'amazon_cells_labelled.txt',
#   900: 'amazon_cells_labelled.txt',
#   901: 'amazon_cells_labelled.txt',
#   902: 'amazon_cells_labelled.txt',
#   903: 'amazon_cells_labelled.txt',
#   904: 'amazon_cells_labelled.txt',
#   905: 'amazon_cells_labelled.txt',
#   906: 'amazon_cells_labelled.txt',
#   907: 'amazon_cells_labelled.txt',
#   908: 'amazon_cells_labelled.txt',
#   909: 'amazon_cells_labelled.txt',
#   910: 'amazon_cells_labelled.txt',
#   911: 'amazon_cells_labelled.txt',
#   912: 'amazon_cells_labelled.txt',
#   913: 'amazon_cells_labelled.txt',
#   914: 'amazon_cells_labelled.txt',
#   915: 'amazon_cells_labelled.txt',
#   916: 'amazon_cells_labelled.txt',
#   917: 'amazon_cells_labelled.txt',
#   918: 'amazon_cells_labelled.txt',
#   919: 'amazon_cells_labelled.txt',
#   920: 'amazon_cells_labelled.txt',
#   921: 'amazon_cells_labelled.txt',
#   922: 'amazon_cells_labelled.txt',
#   923: 'amazon_cells_labelled.txt',
#   924: 'amazon_cells_labelled.txt',
#   925: 'amazon_cells_labelled.txt',
#   926: 'amazon_cells_labelled.txt',
#   927: 'amazon_cells_labelled.txt',
#   928: 'amazon_cells_labelled.txt',
#   929: 'amazon_cells_labelled.txt',
#   930: 'amazon_cells_labelled.txt',
#   931: 'amazon_cells_labelled.txt',
#   932: 'amazon_cells_labelled.txt',
#   933: 'amazon_cells_labelled.txt',
#   934: 'amazon_cells_labelled.txt',
#   935: 'amazon_cells_labelled.txt',
#   936: 'amazon_cells_labelled.txt',
#   937: 'amazon_cells_labelled.txt',
#   938: 'amazon_cells_labelled.txt',
#   939: 'amazon_cells_labelled.txt',
#   940: 'amazon_cells_labelled.txt',
#   941: 'amazon_cells_labelled.txt',
#   942: 'amazon_cells_labelled.txt',
#   943: 'amazon_cells_labelled.txt',
#   944: 'amazon_cells_labelled.txt',
#   945: 'amazon_cells_labelled.txt',
#   946: 'amazon_cells_labelled.txt',
#   947: 'amazon_cells_labelled.txt',
#   948: 'amazon_cells_labelled.txt',
#   949: 'amazon_cells_labelled.txt',
#   950: 'amazon_cells_labelled.txt',
#   951: 'amazon_cells_labelled.txt',
#   952: 'amazon_cells_labelled.txt',
#   953: 'amazon_cells_labelled.txt',
#   954: 'amazon_cells_labelled.txt',
#   955: 'amazon_cells_labelled.txt',
#   956: 'amazon_cells_labelled.txt',
#   957: 'amazon_cells_labelled.txt',
#   958: 'amazon_cells_labelled.txt',
#   959: 'amazon_cells_labelled.txt',
#   960: 'amazon_cells_labelled.txt',
#   961: 'amazon_cells_labelled.txt',
#   962: 'amazon_cells_labelled.txt',
#   963: 'amazon_cells_labelled.txt',
#   964: 'amazon_cells_labelled.txt',
#   965: 'amazon_cells_labelled.txt',
#   966: 'amazon_cells_labelled.txt',
#   967: 'amazon_cells_labelled.txt',
#   968: 'amazon_cells_labelled.txt',
#   969: 'amazon_cells_labelled.txt',
#   970: 'amazon_cells_labelled.txt',
#   971: 'amazon_cells_labelled.txt',
#   972: 'amazon_cells_labelled.txt',
#   973: 'amazon_cells_labelled.txt',
#   974: 'amazon_cells_labelled.txt',
#   975: 'amazon_cells_labelled.txt',
#   976: 'amazon_cells_labelled.txt',
#   977: 'amazon_cells_labelled.txt',
#   978: 'amazon_cells_labelled.txt',
#   979: 'amazon_cells_labelled.txt',
#   980: 'amazon_cells_labelled.txt',
#   981: 'amazon_cells_labelled.txt',
#   982: 'amazon_cells_labelled.txt',
#   983: 'amazon_cells_labelled.txt',
#   984: 'amazon_cells_labelled.txt',
#   985: 'amazon_cells_labelled.txt',
#   986: 'amazon_cells_labelled.txt',
#   987: 'amazon_cells_labelled.txt',
#   988: 'amazon_cells_labelled.txt',
#   989: 'amazon_cells_labelled.txt',
#   990: 'amazon_cells_labelled.txt',
#   991: 'amazon_cells_labelled.txt',
#   992: 'amazon_cells_labelled.txt',
#   993: 'amazon_cells_labelled.txt',
#   994: 'amazon_cells_labelled.txt',
#   995: 'amazon_cells_labelled.txt',
#   996: 'amazon_cells_labelled.txt',
#   997: 'amazon_cells_labelled.txt',
#   998: 'amazon_cells_labelled.txt',
#   999: 'amazon_cells_labelled.txt',
#   ...},
#  'message': {0: 'I try not to adjust the volume setting to avoid that I turn off the call button which is situated just below the volume adjustment knob.',
#   1: 'So there is no way for me to plug it in here in the US unless I go by a converter.',
#   2: 'Good case, Excellent value.',
#   3: 'I thought Motorola made reliable products!.',
#   4: 'Battery for Motorola Razr.',
#   5: 'Great for the jawbone.',
#   6: 'When I got this item it was larger than I thought It was the size of a small video game but bulky.',
#   7: '(I looked for one that specifically said DCU-60 and said it supported USB 1 and 2.',
#   8: 'The first time it was turned on the screen display began to flicker.',
#   9: 'In some programs clicking it is the same as hitting the return key.',
#   10: 'Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!',
#   11: 'The mic is great.',
#   12: 'What happened was that I only had like 70 contacts but the SIM memory said I had 250, and that all my SIM memory was full.',
#   13: 'I have to jiggle the plug to get it to line up right to get decent volume.',
#   14: 'I bought five of thes for less than five dollars.',
#   15: 'If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.',
#   16: 'I had the two year contract for this service.',
#   17: 'If you are Razr owner...you must have this!',
#   18: 'Needless to say, I wasted my money.',
#   19: 'If money is no constraint then just go for it.',
#   20: 'Try texting fast with it...4.',
#   21: 'What a waste of money and time!.',
#   22: 'If you buy this phone and have problems, you need to contact customer service.',
#   23: 'This company will not give me back all of my money back because of their mistakes written in their review that said is made for the Dell Streak.',
#   24: 'And the sound quality is great.',
#   25: 'It made sense.',
#   26: 'He was very impressed when going from the original battery to the extended battery.',
#   27: "Others have complained of chipping paint but in the week I've been using this it hasn't chipped yet.",
#   28: "I'm giving it a third try because I really want this phone to work properly, it has such great potential to be an invaluable business tool.",
#   29: 'If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.',
#   30: 'These are sealed packages by Motorola there is no way that Motorola would put the wrong charger with the wrong unit.',
#   31: 'It made the images look so grainy that you just could not appreciate the beautiful AMOLED screen anymore.',
#   32: 'Very good quality though',
#   33: 'The design is very odd, as the ear "clip" is not very comfortable at all.',
#   34: 'Highly recommend for any one who has a blue tooth phone.',
#   35: 'the pda package runs $40 a month plus $40 a month for service.',
#   36: 'I advise EVERYONE DO NOT BE FOOLED!',
#   37: 'I only took it off approximately 3 times and babied it when I did.',
#   38: 'Unfortunately, I opened both so now I have (2).',
#   39: 'So Far So Good!.',
#   40: 'Works great!.',
#   41: 'It clicks into place in a way that makes you wonder how long that mechanism would last.',
#   42: "I went on Motorola's website and followed all directions, but could not get it to pair again.",
#   43: 'Also to adjust the call volume you have to be talking, just push the over button to the left or right.',
#   44: 'I have patiently waited for a blackberry with Bluetooth and it came!',
#   45: 'I bought this to use with my Kindle Fire and absolutely loved it!',
#   46: 'After this month-long reparte with the J.D.',
#   47: 'Not too bad, I can still use the handset (Motorola E815) to switch between calls.Power button is TINY.',
#   48: 'I choose this because i liked the disign and i thought motorola made good products.',
#   49: 'The battery life is about 2-3x the life of the battery that it is replacing, and as best I can remember about the same as the phone when new.',
#   50: 'My initial impression was the sound quality was good but the workmanship was cheap.',
#   51: 'The commercials are the most misleading.',
#   52: "The first one I washed in my jean's pocket.",
#   53: 'In general, I could see phones having satellite or HD radio on them in the near future.7) Bluetooth capability.',
#   54: "I have yet to run this new battery below two bars and that's three days without charging.",
#   55: 'Press the center button.3.',
#   56: 'I bought it for my mother and she had a problem with the battery.',
#   57: 'I probably was prepared for the worst.',
#   58: "!Unlike others here I have managed to scar the finish...(what can I say, I'm talented) but nothing that causes the phone to be unusable.",
#   59: 'Great Pocket PC / phone combination.',
#   60: "I'd pay a few bucks more for the player with these included and you would probably increase your profit margins to boot.",
#   61: 'The on/off switch is the antenna, which pops in and out to turn the unit on or off.',
#   62: 'No such thing.',
#   63: "I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.",
#   64: "I didn't think that the instructions provided were helpful to me.",
#   65: 'People couldnt hear me talk and I had to pull out the earphone and talk on the phone.',
#   66: "Doesn't hold charge.",
#   67: 'This is a simple little phone to use, but the breakage is unacceptible.',
#   68: 'Since it consumes considerable amount of power, it goes to standby mode quickly and then, when you power it up, it is very slow to get signals.',
#   69: 'This product is ideal for people like me whose ears are very sensitive.',
#   70: 'I have missed more than 50% calls attended on this phone.',
#   71: 'It is unusable in a moving car at freeway speed.',
#   72: 'I just bought this headset for use with an LG VX-8300.',
#   73: 'I have two more years left in this contract and I hate this phone.',
#   74: 'I bought these on sale at a tmobile store b/c i needed a new bluetooth and thought "wow sterio bluetooth".',
#   75: 'I bought this charger for my Pantech PN-215.',
#   76: 'I recently signed up for a two year contract through Amazon.',
#   77: 'I got the battery in the mail.',
#   78: 'Not for everyone.',
#   79: 'Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended',
#   80: 'The synchronization did not work with the phone they advertised as being supported.',
#   81: 'You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.',
#   82: 'It has kept up very well.',
#   83: 'Really boxy sound, and my past 4 headsets of the same kind broke without cause.',
#   84: 'TAKES MOVING IT ABOUT AFTERTRYING DIFFERENT SIZES.',
#   85: "It's not bad, but what do you expect for $3 or however much it is?",
#   86: 'I canceled a line.',
#   87: 'Not sure why they made it that way, but it does have a pretty long charge (longer than my headphones).',
#   88: 'Poor Talk Time Performance.',
#   89: 'But if you want a phone that has a good quality camera, takes videos, and etc.',
#   90: 'The case is great and works fine with the 680.',
#   91: 'worthless product.',
#   92: "(I had used other headsets with wires and wasn't happy with any of them; this is the first headset that I've found to be truly convenient.)",
#   93: 'It has a great camera thats 2MP, and the pics are nice and clear with great picture quality.',
#   94: 'Fast connection speed and solid connection - when your phone rings, you need the headset to react quickly.',
#   95: 'I was not impressed by this product.',
#   96: "(The audio CD's is what I want for my 'final product').",
#   97: 'Nice headset priced right.',
#   98: 'They can make anything.',
#   99: 'I use it for about 6 hours a day and have dropped the earpiece a couple times.',
#   100: 'The closest to a standard ring is the T-Mobile advertisement jingle.',
#   101: 'I only hear garbage for audio.',
#   102: 'It looks like a solid case with all the keys exposed.',
#   103: 'Verizon is a little faster, but $49.95 a month.',
#   104: 'Excellent bluetooth headset.',
#   105: 'It has all the features I want',
#   106: "I cannot review the remote's capabilities since it wouldn't work for this iHome we have.",
#   107: "And so far I haven't found the vibe and then ring option which was available even through the side button of the motorola.3.",
#   108: 'Who in their right mind is gonna buy this battery?.',
#   109: 'AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.',
#   110: 'This case seems well made.',
#   111: "Thank You... Almost perfect.... It's so much easier to carry a cable vs another mini brick for every device you need to charge in your laptop bag.",
#   112: 'Yes, I still think this phone is ridiculas- especially for 100 dollars.',
#   113: "Connected it to a Motorola Cliq running Gingerbread, but the connection wasn't too strong and my conversations were difficult to maintain.",
#   114: 'Disappointed with battery.',
#   115: "Not loud enough and doesn't turn on like it should.",
#   116: 'This is the first headset that gives acceptable sound quality both sending and receiving on my Treo 700P.',
#   117: 'good protection and does not make phone too bulky.',
#   118: 'A usable keyboard actually turns a PDA into a real-world useful machine instead of just a neat gadget.',
#   119: 'This is the second time I have purchased this because my little cousin grabbed and broke the first one.',
#   120: "I don't have to charge my phone half as much as before.",
#   121: 'it lasted about six months.',
#   122: "This phone is pretty sturdy and I've never had any large problems with it.",
#   123: "I don't know if it's T-Mobile though.",
#   124: 'I tried it on my phobe and it was still very bad.',
#   125: 'More bad than good.',
#   126: 'I love this thing!',
#   127: 'Everything about it is fine and reasonable for the price i.e.',
#   128: "And thas about it.It's not the perfect phone.",
#   129: 'Lucky....I guess.',
#   130: 'It also constantly repeats, "Command not recognized...." or it would ask, "Did you say?',
#   131: 'SolidGreat.',
#   132: "And while you can shut off the flashing blue light, you can't do so while you are already on a call.",
#   133: 'If not, it displays the caller id info.5.',
#   134: 'So you can only control the positioning one dimensionally.',
#   135: 'My aim was to find a small, sleek, simple/contemporary looking phone.',
#   136: 'This product did the trick, came with all the necessary chargers, and data cable needed to get the lg scoop connected to my computer.',
#   137: 'VERY DISAPPOINTED.',
#   138: 'I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great!',
#   139: 'I bought this pretty much because of the Monster name.',
#   140: 'I have been very happy with the 510 and have had NO complaints from any one regarding my sound quality on their end.',
#   141: 'I checked the tracking info a couple of days after the order and saw that the company said my product had been delivered last month.',
#   142: 'Was a little surprised to find a 3-pin UK charger (with a cheap nasty adapter for US power outlets).',
#   143: 'The buttons for on and off are bad.',
#   144: 'I have returned my chager to Motorolla under warranty two times.',
#   145: 'All contacts are combined.',
#   146: 'It really is OEM.',
#   147: "Essentially you can forget Microsoft's tech support.",
#   148: "Wish I'd played with it the day it arrived.",
#   149: 'I really recommend this faceplates since it looks very nice, elegant and cool.',
#   150: "These headphones were a great find - and I think they are perhaps the best purchase I've made in the last several years - seriously.",
#   151: 'Buy a different phone - but not this.',
#   152: 'You have to hold the phone at a particular angle for the other party to hear you clearly.',
#   153: 'with my Treo 700w.',
#   154: 'It is a very snug fit, to snug I might add.',
#   155: 'I have been with Cingular 400 Roll over plans for 3 years now.',
#   156: 'This product is not well suited for my LG Vue, I am still looking for a better armband.',
#   157: "So if I can get 2gb of memory in a storage card for under $30, why couldn't they have increased the memory?",
# ...
#   947: 'Even though my primary use is a phone, I still need it to be a PDA/organizer.',
#   948: 'The shipping was quick.',
#   949: 'Works great, when my cat attacked the phone he scratched the protective strip instead of destroying the screen.',
#   950: 'The flap will pop open.I need to get another case.',
#   951: 'I kept the Bose for the office.I purchased the Motorola S805, basically out of sheer desperation.',
#   952: 'This one works and was priced right.',
#   953: "basically a pro is that it's a cellphone3.",
#   954: 'Oh yeah, It seemed as if one of them was already used or at least tried.',
#   955: 'With this tiny fix, you will definitely have the best looking, best performing, and best fitting bluetooth headset out there.',
#   956: "And where's the ZOOM???",
#   957: 'I tried several other inexpensive phones but the clarity was not there.',
#   958: 'If I wanted to be tethered to a wire, I would just use a land line...',
#   959: 'Four months later (yesterday) headset number two died in the same way number one gave up the ghost.',
#   960: 'Customer service was terrible.',
#   961: 'I was promised credit minus a 10% restocking fee IF AND ONLY IF I wrote a review favorable to the seller, which I did.',
#   962: 'Lost this one on a ride at Disney World.',
#   963: 'Battery life still not long enough in Motorola Razor V3i.',
#   964: 'If you need a quick & cheap replacement battery, this would be the way to go.',
#   965: "The sound on my end is not that great, either, though I'm willing to trade that off if my caller says it sounds ok.",
#   966: 'The ad for it sounded good.',
#   967: 'Well, I lost the phone yesterday and believe it or not, I was SOOO happy to lose it.',
#   968: "And the user interface really makes a lot of sense once you've figured out all the shortcuts and stuff.",
#   969: 'So as I went to get my Cingular phone (highly recommended), I had the old number switched to my new number.',
#   970: "There's a joint between the main body of the unit and the panel with the buttons on it which has come apart on all three units I've tried.",
#   971: 'I tried the charger and USB cable on 3 different Samsung phones.',
#   972: 'Sending it back.',
#   973: 'Now I know that I made a wise decision.',
#   974: 'The one thing that is annoying, which other buyers have noticed, is a tendency to reset itself.',
#   975: "It's a wire that you plug into the back of your car stereo.",
#   976: 'Someone shouldve invented this sooner.',
#   977: 'Good price.',
#   978: 'Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good.',
#   979: "I still find the processor to be annoying and T-Mobile's coverage is not the best.",
#   980: 'Sound quality is poor as well...the headsets will go back to vzw..',
#   981: 'The only complaint is that the unit is uncomfortable on my ear after a wearing for a short time.',
#   982: 'Alltel has apparently not disabled this to the extent that others have.',
#   983: 'A different iGo recharger model ($70-$100) for laptops is available and it will also power other electronic gadgets.',
#   984: 'I received it quickly and it works great!!',
#   985: 'It is the same cable included in the kit but does not include the software.',
#   986: 'Has been working great.',
#   987: 'decent phone but gets very poor reception.',
#   988: "As many people complained, I found this headset's microphone was very weak.",
#   989: 'Hello Moto?...',
#   990: 'Suggestion.',
#   991: 'My 5-year old Nokia 2160 from Tracfone holds the charge a lot better than this.',
#   992: "It's small, ergonomically easy to use, and aesthetically pleasing.",
#   993: "I suspect the seller was selling it as new but it is used and they won't take it back.",
#   994: 'They do not care about the consumer one bit.',
#   995: "It's what it says.",
#   996: 'i would recommend u get it .i am getting my next fone in april, and i am looking at the LG chocolate and the EnV.',
#   997: 'The Box is no good without software.',
#   998: 'The phone does charge, but that is all.',
#   999: 'This is a good battery, and it got here really fast.',
#   ...},
#  'sentiment': {0: nan,
#   1: 0.0,
#   2: 1.0,
#   3: nan,
#   4: nan,
#   5: 1.0,
#   6: nan,
#   7: nan,
#   8: nan,
#   9: nan,
#   10: 0.0,
#   11: 1.0,
#   12: nan,
#   13: 0.0,
#   14: nan,
#   15: 0.0,
#   16: nan,
#   17: 1.0,
#   18: 0.0,
#   19: nan,
#   20: nan,
#   21: 0.0,
#   22: nan,
#   23: nan,
#   24: 1.0,
#   25: nan,
#   26: 1.0,
#   27: nan,
#   28: nan,
#   29: 0.0,
#   30: nan,
#   31: nan,
#   32: 1.0,
#   33: 0.0,
#   34: 1.0,
#   35: nan,
#   36: 0.0,
#   37: nan,
#   38: nan,
#   39: 1.0,
#   40: 1.0,
#   41: 0.0,
#   42: 0.0,
#   43: nan,
#   44: nan,
#   45: 1.0,
#   46: nan,
#   47: nan,
#   48: nan,
#   49: nan,
#   50: nan,
#   51: 0.0,
#   52: nan,
#   53: nan,
#   54: 1.0,
#   55: nan,
#   56: 0.0,
#   57: nan,
#   58: nan,
#   59: 1.0,
#   60: nan,
#   61: nan,
#   62: nan,
#   63: 1.0,
#   64: 0.0,
#   65: 0.0,
#   66: 0.0,
#   67: 0.0,
#   68: nan,
#   69: 1.0,
#   70: nan,
#   71: 0.0,
#   72: nan,
#   73: 0.0,
#   74: nan,
#   75: nan,
#   76: nan,
#   77: nan,
#   78: nan,
#   79: 1.0,
#   80: nan,
#   81: 0.0,
#   82: 1.0,
#   83: nan,
#   84: nan,
#   85: nan,
#   86: nan,
#   87: nan,
#   88: 0.0,
#   89: nan,
#   90: 1.0,
#   91: 0.0,
#   92: nan,
#   93: 1.0,
#   94: nan,
#   95: 0.0,
#   96: nan,
#   97: 1.0,
#   98: nan,
#   99: nan,
#   100: nan,
#   101: 0.0,
#   102: nan,
#   103: nan,
#   104: 1.0,
#   105: 1.0,
#   106: nan,
#   107: nan,
#   108: 0.0,
#   109: 0.0,
#   110: 1.0,
#   111: nan,
#   112: nan,
#   113: nan,
#   114: 0.0,
#   115: 0.0,
#   116: nan,
#   117: 1.0,
#   118: 1.0,
#   119: nan,
#   120: nan,
#   121: nan,
#   122: 1.0,
#   123: nan,
#   124: nan,
#   125: nan,
#   126: 1.0,
#   127: 1.0,
#   128: nan,
#   129: nan,
#   130: nan,
#   131: nan,
#   132: nan,
#   133: nan,
#   134: nan,
#   135: nan,
#   136: nan,
#   137: 0.0,
#   138: 1.0,
#   139: nan,
#   140: 1.0,
#   141: nan,
#   142: nan,
#   143: 0.0,
#   144: nan,
#   145: nan,
#   146: nan,
#   147: 0.0,
#   148: nan,
#   149: 1.0,
#   150: 1.0,
#   151: 0.0,
#   152: 0.0,
#   153: nan,
#   154: nan,
#   155: nan,
#   156: nan,
#   157: nan,
#   158: nan,
#   159: 0.0,
#   160: 0.0,
#   161: 1.0,
#   162: 1.0,
#   163: nan,
#   164: nan,
#   165: 1.0,
#   166: 0.0,
#   167: nan,
#   168: nan,
#   169: nan,
#   170: nan,
#   171: nan,
#   172: nan,
#   173: 0.0,
#   174: 1.0,
#   175: nan,
#   176: 1.0,
#   177: nan,
#   178: nan,
#   179: 1.0,
#   180: 1.0,
#   181: 0.0,
#   182: nan,
#   183: nan,
#   184: nan,
#   185: nan,
#   186: 1.0,
#   187: nan,
#   188: nan,
#   189: nan,
#   190: 1.0,
#   191: 0.0,
#   192: nan,
#   193: 1.0,
#   194: 0.0,
#   195: 1.0,
#   196: nan,
#   197: nan,
#   198: nan,
#   199: nan,
#   200: 0.0,
#   201: 0.0,
#   202: 1.0,
#   203: 1.0,
#   204: nan,
#   205: nan,
#   206: nan,
#   207: nan,
#   208: nan,
#   209: nan,
#   210: 0.0,
#   211: nan,
#   212: 1.0,
#   213: nan,
#   214: 1.0,
#   215: nan,
#   216: nan,
#   217: nan,
#   218: nan,
#   219: 0.0,
#   220: nan,
#   221: nan,
#   222: nan,
#   223: nan,
#   224: nan,
#   225: nan,
#   226: nan,
#   227: nan,
#   228: nan,
#   229: nan,
#   230: 1.0,
#   231: 1.0,
#   232: nan,
#   233: nan,
#   234: nan,
#   235: nan,
#   236: nan,
#   237: 0.0,
#   238: 0.0,
#   239: nan,
#   240: nan,
#   241: nan,
#   242: 1.0,
#   243: nan,
#   244: 0.0,
#   245: nan,
#   246: nan,
#   247: 0.0,
#   248: 1.0,
#   249: 0.0,
#   250: 1.0,
#   251: nan,
#   252: nan,
#   253: nan,
#   254: nan,
#   255: nan,
#   256: 0.0,
#   257: nan,
#   258: nan,
#   259: nan,
#   260: nan,
#   261: nan,
#   262: nan,
#   263: nan,
#   264: 1.0,
#   265: nan,
#   266: 1.0,
#   267: 0.0,
#   268: 1.0,
#   269: nan,
#   270: 0.0,
#   271: nan,
#   272: nan,
#   273: nan,
#   274: nan,
#   275: 1.0,
#   276: 0.0,
#   277: 0.0,
#   278: 1.0,
#   279: nan,
#   280: nan,
#   281: nan,
#   282: 1.0,
#   283: 1.0,
#   284: nan,
#   285: nan,
#   286: nan,
#   287: nan,
#   288: nan,
#   289: 1.0,
#   290: nan,
#   291: 1.0,
#   292: nan,
#   293: 1.0,
#   294: nan,
#   295: nan,
#   296: 0.0,
#   297: nan,
#   298: nan,
#   299: 1.0,
#   300: 1.0,
#   301: nan,
#   302: nan,
#   303: nan,
#   304: nan,
#   305: nan,
#   306: 1.0,
#   307: 1.0,
#   308: nan,
#   309: 0.0,
#   310: nan,
#   311: nan,
#   312: nan,
#   313: nan,
#   314: nan,
#   315: 1.0,
#   316: nan,
#   317: nan,
#   318: nan,
#   319: 0.0,
#   320: 1.0,
#   321: 1.0,
#   322: nan,
#   323: nan,
#   324: nan,
#   325: 0.0,
#   326: nan,
#   327: nan,
#   328: nan,
#   329: nan,
#   330: nan,
#   331: nan,
#   332: nan,
#   333: nan,
#   334: 0.0,
#   335: nan,
#   336: 1.0,
#   337: nan,
#   338: nan,
#   339: 0.0,
#   340: 1.0,
#   341: nan,
#   342: 1.0,
#   343: nan,
#   344: nan,
#   345: nan,
#   346: 1.0,
#   347: 1.0,
#   348: nan,
#   349: nan,
#   350: nan,
#   351: 0.0,
#   352: nan,
#   353: nan,
#   354: nan,
#   355: nan,
#   356: nan,
#   357: nan,
#   358: nan,
#   359: nan,
#   360: nan,
#   361: nan,
#   362: nan,
#   363: nan,
#   364: 0.0,
#   365: nan,
#   366: nan,
#   367: nan,
#   368: 1.0,
#   369: nan,
#   370: nan,
#   371: nan,
#   372: nan,
#   373: nan,
#   374: nan,
#   375: nan,
#   376: 1.0,
#   377: nan,
#   378: nan,
#   379: nan,
#   380: nan,
#   381: nan,
#   382: 0.0,
#   383: nan,
#   384: nan,
#   385: nan,
#   386: nan,
#   387: 1.0,
#   388: nan,
#   389: 0.0,
#   390: nan,
#   391: nan,
#   392: 0.0,
#   393: nan,
#   394: nan,
#   395: nan,
#   396: 0.0,
#   397: 0.0,
#   398: nan,
#   399: nan,
#   400: nan,
#   401: nan,
#   402: 0.0,
#   403: 1.0,
#   404: 0.0,
#   405: nan,
#   406: nan,
#   407: nan,
#   408: nan,
#   409: 0.0,
#   410: 0.0,
#   411: nan,
#   412: nan,
#   413: 0.0,
#   414: nan,
#   415: nan,
#   416: nan,
#   417: nan,
#   418: 0.0,
#   419: nan,
#   420: nan,
#   421: nan,
#   422: nan,
#   423: 0.0,
#   424: nan,
#   425: 1.0,
#   426: nan,
#   427: nan,
#   428: nan,
#   429: nan,
#   430: nan,
#   431: nan,
#   432: nan,
#   433: nan,
#   434: nan,
#   435: nan,
#   436: nan,
#   437: 1.0,
#   438: nan,
#   439: nan,
#   440: 0.0,
#   441: nan,
#   442: nan,
#   443: nan,
#   444: nan,
#   445: nan,
#   446: nan,
#   447: nan,
#   448: nan,
#   449: nan,
#   450: nan,
#   451: 1.0,
#   452: nan,
#   453: 1.0,
#   454: nan,
#   455: nan,
#   456: 1.0,
#   457: nan,
#   458: nan,
#   459: nan,
#   460: 1.0,
#   461: nan,
#   462: nan,
#   463: nan,
#   464: 1.0,
#   465: nan,
#   466: nan,
#   467: nan,
#   468: nan,
#   469: nan,
#   470: 0.0,
#   471: nan,
#   472: nan,
#   473: nan,
#   474: nan,
#   475: nan,
#   476: nan,
#   477: nan,
#   478: nan,
#   479: nan,
#   480: nan,
#   481: nan,
#   482: nan,
#   483: nan,
#   484: nan,
#   485: 1.0,
#   486: nan,
#   487: nan,
#   488: nan,
#   489: 0.0,
#   490: nan,
#   491: 1.0,
#   492: nan,
#   493: nan,
#   494: nan,
#   495: nan,
#   496: nan,
#   497: 0.0,
#   498: nan,
#   499: nan,
#   500: nan,
#   501: nan,
#   502: nan,
#   503: 1.0,
#   504: nan,
#   505: nan,
#   506: 0.0,
#   507: nan,
#   508: nan,
#   509: nan,
#   510: nan,
#   511: 1.0,
#   512: nan,
#   513: nan,
#   514: 0.0,
#   515: nan,
#   516: nan,
#   517: 0.0,
#   518: 1.0,
#   519: 0.0,
#   520: nan,
#   521: nan,
#   522: nan,
#   523: nan,
#   524: 0.0,
#   525: 1.0,
#   526: nan,
#   527: 1.0,
#   528: nan,
#   529: nan,
#   530: nan,
#   531: nan,
#   532: nan,
#   533: nan,
#   534: nan,
#   535: nan,
#   536: nan,
#   537: nan,
#   538: 1.0,
#   539: 1.0,
#   540: 0.0,
#   541: nan,
#   542: 0.0,
#   543: 0.0,
#   544: 0.0,
#   545: nan,
#   546: 0.0,
#   547: 1.0,
#   548: 0.0,
#   549: nan,
#   550: nan,
#   551: nan,
#   552: 0.0,
#   553: 1.0,
#   554: 0.0,
#   555: nan,
#   556: nan,
#   557: nan,
#   558: nan,
#   559: 1.0,
#   560: nan,
#   561: nan,
#   562: nan,
#   563: 0.0,
#   564: 0.0,
#   565: nan,
#   566: 0.0,
#   567: 1.0,
#   568: nan,
#   569: nan,
#   570: nan,
#   571: nan,
#   572: nan,
#   573: 1.0,
#   574: nan,
#   575: nan,
#   576: 0.0,
#   577: nan,
#   578: 0.0,
#   579: nan,
#   580: nan,
#   581: 1.0,
#   582: 1.0,
#   583: 0.0,
#   584: 0.0,
#   585: nan,
#   586: nan,
#   587: nan,
#   588: 0.0,
#   589: nan,
#   590: nan,
#   591: nan,
#   592: 1.0,
#   593: nan,
#   594: nan,
#   595: 1.0,
#   596: 0.0,
#   597: 1.0,
#   598: nan,
#   599: nan,
#   600: nan,
#   601: nan,
#   602: nan,
#   603: 0.0,
#   604: nan,
#   605: nan,
#   606: 1.0,
#   607: 1.0,
#   608: nan,
#   609: 1.0,
#   610: 1.0,
#   611: nan,
#   612: nan,
#   613: nan,
#   614: nan,
#   615: nan,
#   616: nan,
#   617: nan,
#   618: 0.0,
#   619: 0.0,
#   620: 0.0,
#   621: nan,
#   622: nan,
#   623: nan,
#   624: nan,
#   625: nan,
#   626: nan,
#   627: nan,
#   628: 1.0,
#   629: 1.0,
#   630: nan,
#   631: nan,
#   632: nan,
#   633: nan,
#   634: nan,
#   635: 1.0,
#   636: nan,
#   637: nan,
#   638: nan,
#   639: nan,
#   640: nan,
#   641: 1.0,
#   642: nan,
#   643: nan,
#   644: nan,
#   645: nan,
#   646: nan,
#   647: nan,
#   648: 1.0,
#   649: nan,
#   650: nan,
#   651: nan,
#   652: 0.0,
#   653: nan,
#   654: nan,
#   655: nan,
#   656: 0.0,
#   657: nan,
#   658: 1.0,
#   659: nan,
#   660: nan,
#   661: nan,
#   662: nan,
#   663: 0.0,
#   664: nan,
#   665: nan,
#   666: nan,
#   667: nan,
#   668: nan,
#   669: nan,
#   670: nan,
#   671: nan,
#   672: 0.0,
#   673: 1.0,
#   674: nan,
#   675: nan,
#   676: nan,
#   677: 0.0,
#   678: nan,
#   679: nan,
#   680: nan,
#   681: nan,
#   682: nan,
#   683: nan,
#   684: nan,
#   685: 0.0,
#   686: nan,
#   687: 1.0,
#   688: 1.0,
#   689: 0.0,
#   690: nan,
#   691: nan,
#   692: 0.0,
#   693: 0.0,
#   694: nan,
#   695: nan,
#   696: nan,
#   697: nan,
#   698: nan,
#   699: nan,
#   700: 0.0,
#   701: nan,
#   702: 0.0,
#   703: 0.0,
#   704: 1.0,
#   705: nan,
#   706: nan,
#   707: nan,
#   708: 1.0,
#   709: nan,
#   710: nan,
#   711: nan,
#   712: 1.0,
#   713: nan,
#   714: nan,
#   715: nan,
#   716: nan,
#   717: nan,
#   718: nan,
#   719: nan,
#   720: nan,
#   721: nan,
#   722: nan,
#   723: nan,
#   724: 1.0,
#   725: nan,
#   726: nan,
#   727: nan,
#   728: nan,
#   729: 1.0,
#   730: nan,
#   731: 1.0,
#   732: 0.0,
#   733: nan,
#   734: nan,
#   735: nan,
#   736: 0.0,
#   737: nan,
#   738: nan,
#   739: 0.0,
#   740: 0.0,
#   741: nan,
#   742: nan,
#   743: nan,
#   744: nan,
#   745: 0.0,
#   746: nan,
#   747: nan,
#   748: nan,
#   749: nan,
#   750: nan,
#   751: nan,
#   752: nan,
#   753: nan,
#   754: nan,
#   755: 0.0,
#   756: nan,
#   757: nan,
#   758: nan,
#   759: nan,
#   760: 1.0,
#   761: nan,
#   762: nan,
#   763: nan,
#   764: nan,
#   765: nan,
#   766: 1.0,
#   767: nan,
#   768: nan,
#   769: nan,
#   770: nan,
#   771: 1.0,
#   772: 0.0,
#   773: nan,
#   774: nan,
#   775: nan,
#   776: nan,
#   777: nan,
#   778: nan,
#   779: nan,
#   780: nan,
#   781: nan,
#   782: 1.0,
#   783: 1.0,
#   784: nan,
#   785: 1.0,
#   786: nan,
#   787: 1.0,
#   788: nan,
#   789: nan,
#   790: nan,
#   791: 1.0,
#   792: 0.0,
#   793: nan,
#   794: nan,
#   795: nan,
#   796: nan,
#   797: nan,
#   798: nan,
#   799: 0.0,
#   800: nan,
#   801: nan,
#   802: nan,
#   803: 0.0,
#   804: 1.0,
#   805: nan,
#   806: 1.0,
#   807: 1.0,
#   808: 1.0,
#   809: nan,
#   810: 1.0,
#   811: nan,
#   812: nan,
#   813: 1.0,
#   814: nan,
#   815: 0.0,
#   816: nan,
#   817: nan,
#   818: nan,
#   819: nan,
#   820: 0.0,
#   821: nan,
#   822: nan,
#   823: nan,
#   824: 1.0,
#   825: 0.0,
#   826: nan,
#   827: 1.0,
#   828: 0.0,
#   829: 1.0,
#   830: nan,
#   831: nan,
#   832: nan,
#   833: nan,
#   834: nan,
#   835: 0.0,
#   836: nan,
#   837: nan,
#   838: nan,
#   839: 1.0,
#   840: nan,
#   841: nan,
#   842: nan,
#   843: nan,
#   844: 0.0,
#   845: nan,
#   846: nan,
#   847: 1.0,
#   848: nan,
#   849: 0.0,
#   850: nan,
#   851: nan,
#   852: nan,
#   853: nan,
#   854: nan,
#   855: nan,
#   856: nan,
#   857: nan,
#   858: nan,
#   859: nan,
#   860: nan,
#   861: 1.0,
#   862: 0.0,
#   863: nan,
#   864: nan,
#   865: nan,
#   866: 1.0,
#   867: nan,
#   868: nan,
#   869: nan,
#   870: 1.0,
#   871: nan,
#   872: 1.0,
#   873: 1.0,
#   874: 1.0,
#   875: 0.0,
#   876: nan,
#   877: nan,
#   878: nan,
#   879: nan,
#   880: 1.0,
#   881: nan,
#   882: nan,
#   883: nan,
#   884: nan,
#   885: nan,
#   886: nan,
#   887: nan,
#   888: nan,
#   889: nan,
#   890: nan,
#   891: nan,
#   892: nan,
#   893: nan,
#   894: nan,
#   895: nan,
#   896: nan,
#   897: nan,
#   898: nan,
#   899: 1.0,
#   900: 1.0,
#   901: nan,
#   902: nan,
#   903: 0.0,
#   904: nan,
#   905: nan,
#   906: nan,
#   907: nan,
#   908: nan,
#   909: nan,
#   910: 0.0,
#   911: 0.0,
#   912: 1.0,
#   913: nan,
#   914: nan,
#   915: 1.0,
#   916: nan,
#   917: nan,
#   918: nan,
#   919: nan,
#   920: nan,
#   921: nan,
#   922: nan,
#   923: nan,
#   924: nan,
#   925: nan,
#   926: nan,
#   927: nan,
#   928: nan,
#   929: nan,
#   930: nan,
#   931: nan,
#   932: nan,
#   933: nan,
#   934: nan,
#   935: nan,
#   936: nan,
#   937: 0.0,
#   938: nan,
#   939: 1.0,
#   940: 0.0,
#   941: nan,
#   942: nan,
#   943: nan,
#   944: 1.0,
#   945: nan,
#   946: 1.0,
#   947: nan,
#   948: nan,
#   949: 1.0,
#   950: nan,
#   951: nan,
#   952: 1.0,
#   953: nan,
#   954: nan,
#   955: nan,
#   956: nan,
#   957: nan,
#   958: nan,
#   959: nan,
#   960: 0.0,
#   961: nan,
#   962: nan,
#   963: 0.0,
#   964: nan,
#   965: nan,
#   966: nan,
#   967: nan,
#   968: nan,
#   969: nan,
#   970: nan,
#   971: nan,
#   972: 0.0,
#   973: 1.0,
#   974: nan,
#   975: nan,
#   976: 1.0,
#   977: 1.0,
#   978: 1.0,
#   979: nan,
#   980: nan,
#   981: nan,
#   982: nan,
#   983: nan,
#   984: 1.0,
#   985: nan,
#   986: 1.0,
#   987: nan,
#   988: 0.0,
#   989: nan,
#   990: nan,
#   991: 0.0,
#   992: nan,
#   993: nan,
#   994: 0.0,
#   995: nan,
#   996: nan,
#   997: nan,
#   998: nan,
#   999: 1.0,
#   ...}}

# %%
"""Make label for file from file path.

    fromFilePath : Input file path.
    Returns      : String label.

    Sample output:

    '../abc/xyz_labelled.txt' -> 'xyz'
    """

def makeLabel(fromFilePath):
    label = os.path.basename(fromFilePath)
    return label[:label.rfind('_')]

# %%
print makeLabel("C:/Users/Rohan/Downloads/trial-run-recruitment-task/trial-run-recruitment-task/data/amazon_cells_labelled.txt")
# Out:
# amazon_cells

# %%
"""Concatenate DataFrames by rows adding a column that indicates the
    source of the message. Make sure that the index for each row is unique.

    Sample output:

                                             messages  sentiment         label
    The CG opening sequence in space looked like i...          0          imdb
    Then one day, I went to use them and the recie...        NaN  amazon_cells
    And the pho is much better when it is served f...        NaN          yelp
    I have always had cases for my cell phones bec...        NaN  amazon_cells
                    I'll let you know how it goes....        NaN          yelp
                                  It looks very nice.          1  amazon_cells
        The Veggitarian platter is out of this world!          1          yelp
                  It looked like a wonderful story.            1          imdb
                       Too much hassle for my liking.        NaN  amazon_cells
    So far so good with this one, plus the glowing...        NaN  amazon_cells
    """

def concatDataFrames(msgDFDict,labelFunc):
    df = DataFrame(msgDFDict)
    df['label'] = df['label'].apply(labelFunc)
    return df

# %%
msgDF = concatDataFrames(msgDFDict,makeLabel)
msgDF = msgDF[np.isfinite(msgDF['sentiment'])].reset_index(drop=True)

msgDF.head()
# Out:
#           label                                            message  sentiment
# 0  amazon_cells  So there is no way for me to plug it in here i...          0
# 1  amazon_cells                        Good case, Excellent value.          1
# 2  amazon_cells                             Great for the jawbone.          1
# 3  amazon_cells  Tied to charger for conversations lasting more...          0
# 4  amazon_cells                                  The mic is great.          1

# %%
def makeTermsFrom(msg):
    """Use this function to convert a message into vocabulary terms to
    avoid confusion regarding what is a valid term.
    """
    
    return [m for m in msg.lower().split() if m]

# %%
msgDF['message'] = msgDF['message'].apply(makeTermsFrom)

# %%
msgDF.head()
# Out:
#           label                                            message  sentiment
# 0  amazon_cells  [so, there, is, no, way, for, me, to, plug, it...          0
# 1  amazon_cells                   [good, case,, excellent, value.]          1
# 2  amazon_cells                        [great, for, the, jawbone.]          1
# 3  amazon_cells  [tied, to, charger, for, conversations, lastin...          0
# 4  amazon_cells                             [the, mic, is, great.]          1

# %%
def countVocabulary(msgsDF):
    """Take a DF of messages, sentiments, and labels and return a DF with
    terms, sentiments, labels, and the corresponding counts. Write
    whatever helper functions are required to achieve this task.

    Sample output:
              term  sentiment         label  count
    0            !          0  amazon_cells      1
    1            !          0          yelp      1
    2            !          1  amazon_cells      1
    3            !          1          imdb      1
    4            !          1          yelp      1
    5           !!          1  amazon_cells      1
    6          !!!          1          yelp      1
    7     !....the          0          yelp      1
    8          !2.          1  amazon_cells      1
    9           !i          1  amazon_cells      1
    10       "1.2"          1  amazon_cells      1
    11        "10"          1          imdb      1
    12          "a          1          imdb      1
    13     "about"          1          imdb      1
    14     "acting          1          imdb      1
    15        "are          0          yelp      1
    16        "art          1          imdb      1
    17         "at          1          imdb      1
    18        "big          1          imdb      1
    19  "breeders"          0          imdb      1
    20      "clip"          0  amazon_cells      1
    21   "collect"          0          imdb      1
    22    "crumby"          0          yelp      1
    23        "don          1          imdb      1
    24        "eel          0          yelp      1
    """
    df = DataFrame()
    for msg, stmt,lbl in zip(msgsDF.message,msgsDF.sentiment,msgsDF.label):
        for m in msg:
            df = df.append(DataFrame({'term':[m],'sentiment':[stmt],'label':[lbl]}))
    for name, group in df.groupby(['term','sentiment','label']):
        df['count'] = group.term.count()
    df = df.reset_index(drop=True)
    return df

# %%
counts = countVocabulary(msgDF.tail(10))

# %%
counts
# Out:
#     label  sentiment     term  count
# 0    yelp          0      the      1
# 1    yelp          0  refried      1
# 2    yelp          0    beans      1
# 3    yelp          0     that      1
# 4    yelp          0     came      1
# 5    yelp          0     with      1
# 6    yelp          0       my      1
# 7    yelp          0     meal      1
# 8    yelp          0     were      1
# 9    yelp          0    dried      1
# 10   yelp          0      out      1
# 11   yelp          0      and      1
# 12   yelp          0   crusty      1
# 13   yelp          0      and      1
# 14   yelp          0      the      1
# 15   yelp          0     food      1
# 16   yelp          0      was      1
# 17   yelp          0   bland.      1
# 18   yelp          0    spend      1
# 19   yelp          0     your      1
# 20   yelp          0    money      1
# 21   yelp          0      and      1
# 22   yelp          0     time      1
# 23   yelp          0     some      1
# 24   yelp          0    place      1
# 25   yelp          0    else.      1
# 26   yelp          0        a      1
# 27   yelp          0     lady      1
# 28   yelp          0       at      1
# 29   yelp          0      the      1
# ..    ...        ...      ...    ...
# 96   yelp          0     next      1
# 97   yelp          0    time.      1
# 98   yelp          0    then,      1
# 99   yelp          0       as      1
# 100  yelp          0       if      1
# 101  yelp          0        i      1
# 102  yelp          0   hadn't      1
# 103  yelp          0   wasted      1
# 104  yelp          0   enough      1
# 105  yelp          0       of      1
# 106  yelp          0       my      1
# 107  yelp          0     life      1
# 108  yelp          0   there,      1
# 109  yelp          0     they      1
# 110  yelp          0   poured      1
# 111  yelp          0     salt      1
# 112  yelp          0       in      1
# 113  yelp          0      the      1
# 114  yelp          0    wound      1
# 115  yelp          0       by      1
# 116  yelp          0  drawing      1
# 117  yelp          0      out      1
# 118  yelp          0      the      1
# 119  yelp          0     time      1
# 120  yelp          0       it      1
# 121  yelp          0     took      1
# 122  yelp          0       to      1
# 123  yelp          0    bring      1
# 124  yelp          0      the      1
# 125  yelp          0   check.      1
#
# [126 rows x 4 columns]
